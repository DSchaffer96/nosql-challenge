# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
from pymongo import MongoClient
import pandas as pd
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query ={'scores.Hygiene':{'$eq':20}}

# Use count_documents to display the number of documents in the result
hygiene_count=db.establishments.count_documents(query)
# Display the first document in the results using pprint
hygiene_results=db.establishments.find(query)

print(hygiene_count)
pprint(hygiene_results[1])
# Out:
# 41
# {'AddressLine1': 'Hall Lane',
#  'AddressLine2': 'Walton-on-the-Naze',
#  'AddressLine3': 'Essex',
#  'AddressLine4': '',
#  'BusinessName': 'Brenalwood',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4617.965823673803,
#  'FHRSID': 612039,
#  'LocalAuthorityBusinessID': '1970/FOOD',
#  'LocalAuthorityCode': '120',
#  'LocalAuthorityEmailAddress': 'fhsadmin@tendringdc.gov.uk',
#  'LocalAuthorityName': 'Tendring',
#  'LocalAuthorityWebSite': 'http://www.tendringdc.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CO14 8HN',
#  'RatingDate': '2022-06-22T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('663ffe282914c712c00cae3a'),
#  'geocode': {'latitude': 51.857536, 'longitude': 1.278721},
#  "geocode':{'latitude'}": None,
#  "geocode':{'longitude'}": None,
#  "geocode:{'latitude'}": None,
#  'latitute': None,
# ...

# %%
# Convert the result to a Pandas DataFrame
hygiene_results_df=pd.DataFrame(hygiene_results)
# Display the number of rows in the DataFrame
print(len(hygiene_results_df))
# Display the first 10 rows of the DataFrame
hygiene_results_df.head(10)
# Out:
# 41
#                         _id   FHRSID  ChangesByServerID  \
# 0  663ffe282914c712c00caaba   110681                  0
# 1  663ffe282914c712c00cae3a   612039                  0
# 2  663ffe292914c712c00cb14e   730933                  0
# 3  663ffe292914c712c00cb332   172735                  0
# 4  663ffe292914c712c00cb342   172953                  0
# 5  663ffe292914c712c00cbce7   512854                  0
# 6  663ffe292914c712c00cbf09  1537089                  0
# 7  663ffe292914c712c00cd461   155648                  0
# 8  663ffe292914c712c00cd87a  1012883                  0
# 9  663ffe292914c712c00ce084   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query ={'RatingValue':{'$gte':4},'AddressLine2':{'$regex':'London'}}

# Use count_documents to display the number of documents in the result
rating_count=db.establishments.count_documents(query)
# Display the first document in the results using pprint
rating_results=db.establishments.find(query)

print(rating_count)
pprint(rating_results[1])
# Out:
# 404
# {'AddressLine1': 'Tanglewood',
#  'AddressLine2': '40 London Road',
#  'AddressLine3': 'Canterbury',
#  'AddressLine4': '',
#  'BusinessName': 'Acacia Lodge',
#  'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  'ChangesByServerID': 0,
#  'Distance': 4603.901534746149,
#  'FHRSID': 1102585,
#  'LocalAuthorityBusinessID': '57305',
#  'LocalAuthorityCode': '180',
#  'LocalAuthorityEmailAddress': ' ',
#  'LocalAuthorityName': 'Canterbury City',
#  'LocalAuthorityWebSite': 'http://www.canterbury.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT2 8LF',
#  'RatingDate': '2017-08-31T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('663ffe282914c712c00c9c69'),
#  'geocode': {'latitude': 51.2831611, 'longitude': 1.0676288},
#  "geocode':{'latitude'}": None,
#  "geocode':{'longitude'}": None,
#  "geocode:{'latitude'}": None,
#  'latitute': None,
# ...

# %%
# Convert the result to a Pandas DataFrame
rating_results_df=pd.DataFrame(rating_results)
# Display the number of rows in the DataFrame
print(len(rating_results_df))
# Display the first 10 rows of the DataFrame
rating_results_df.head(10)
# Out:
# 31257
#                         _id   FHRSID  ChangesByServerID  \
# 0  663ffe282914c712c00c8f85  1043695                  0
# 1  663ffe282914c712c00c8f86   647177                  0
# 2  663ffe282914c712c00c8f8b   289560                  0
# 3  663ffe282914c712c00c8f8c   987206                  0
# 4  663ffe282914c712c00c8f8f   344689                  0
# 5  663ffe282914c712c00c8f90   894592                  0
# 6  663ffe282914c712c00c8f91  1043701                  0
# 7  663ffe282914c712c00c8f92   805702                  0
# 8  663ffe282914c712c00c8f93   805703                  0
# 9  663ffe282914c712c00c8f94  1071930                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0             PI/000073616               The Pavilion
# 1             PI/000041489        Wear Bay Bowls Club
# 2             PI/000039927                    Mariner
# 3             PI/000075655           The Ships Galley
# 4             PI/000002095   Folkestone Trawlers Shop
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude =51.49014200
longitude =0.08384000

query ={'RatingValue':{'$eq':5},
        'geocode.latitude':{'$gte':(latitude-degree_search)},
        'geocode.latitude':{'$lte':(latitude+degree_search)},
        'geocode.longitude':{'$gte':(longitude-degree_search)},
        'geocode.longitude':{'$lte':(longitude+degree_search)}
        }
        
sort =[('scores.Hygiene',-1)]
limit =5

penang_results=list(establishments.find(query).sort(sort).limit(limit))
     
# Print the results
pprint(penang_results)
# Out:
# [{'AddressLine1': 'The Buckle',
#   'AddressLine2': 'Marine Parade',
#   'AddressLine3': 'Seaford',
#   'AddressLine4': '',
#   'BusinessName': 'Buckle B&B',
#   'BusinessType': 'Hotel/bed & breakfast/guest house',
#   'BusinessTypeID': 7842,
#   'ChangesByServerID': 0,
#   'Distance': 4621.5144405665105,
#   'FHRSID': 964681,
#   'LocalAuthorityBusinessID': 'PI/000026347',
#   'LocalAuthorityCode': '105',
#   'LocalAuthorityEmailAddress': 'ehealth.ldc@lewes-eastbourne.gov.uk',
#   'LocalAuthorityName': 'Lewes',
#   'LocalAuthorityWebSite': 'http://www.lewes-eastbourne.gov.uk/',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'BN25 2QR',
#   'RatingDate': '2021-01-08T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('663ffe292914c712c00cb58e'),
#   'geocode': {'latitude': 50.779366, 'longitude': 0.080909},
# ...

# %%
# Convert result to Pandas DataFrame
penang_df=pd.DataFrame(penang_results)
penang_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  663ffe292914c712c00cb58e   964681                  0
# 1  663ffe292914c712c00cb537   799755                  0
# 2  663ffe292914c712c00cb6e1  1412076                  0
# 3  663ffe292914c712c00cb6cc  1264191                  0
# 4  663ffe292914c712c00cb49a   664257                  0
#
#   LocalAuthorityBusinessID             BusinessName  \
# 0             PI/000026347               Buckle B&B
# 1             PI/000062948  Co-Operative Food Store
# 2             PI/000066449      Thai Star Foods Ltd
# 3             PI/000064924              Mamoosh Ltd
# 4             PI/000027811           R & B Fish Bar
#
#                             BusinessType  BusinessTypeID       AddressLine1  \
# 0      Hotel/bed & breakfast/guest house            7842         The Buckle
# 1  Retailers - supermarkets/hypermarkets            7840      Units 1 And 2
# 2                    Importers/Exporters              14    Logistics House
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
# 1. Matches establishments with a hygiene score of 0
match_query={'$match':{'scores.Hygiene':{'$eq':0}}}
# 2. Groups the matches by Local Authority
group_query={'$group':{'_id':"$LocalAuthorityName",
                       'count':{'$sum':1}
                      }
            }
# 3. Sorts the matches from highest to lowest
sort_values={'$sort':{'count':-1}}

pipeline=[match_query,group_query,sort_values]
zero_hygiene_results=list(establishments.aggregate(pipeline))

# Print the number of documents in the result
print(len(zero_hygiene_results))
# Print the first 10 results
pprint(results[0:10])
# Out:
# 55
# [{'AddressLine1': 'The Buckle',
#   'AddressLine2': 'Marine Parade',
#   'AddressLine3': 'Seaford',
#   'AddressLine4': '',
#   'BusinessName': 'Buckle B&B',
#   'BusinessType': 'Hotel/bed & breakfast/guest house',
#   'BusinessTypeID': 7842,
#   'ChangesByServerID': 0,
#   'Distance': 4621.5144405665105,
#   'FHRSID': 964681,
#   'LocalAuthorityBusinessID': 'PI/000026347',
#   'LocalAuthorityCode': '105',
#   'LocalAuthorityEmailAddress': 'ehealth.ldc@lewes-eastbourne.gov.uk',
#   'LocalAuthorityName': 'Lewes',
#   'LocalAuthorityWebSite': 'http://www.lewes-eastbourne.gov.uk/',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'BN25 2QR',
#   'RatingDate': '2021-01-08T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('663ffe292914c712c00cb58e'),
#   'geocode': {'latitude': 50.779366, 'longitude': 0.080909},
# ...

# %%
# Convert the result to a Pandas DataFrame
zero_hygiene_df=pd.DataFrame(zero_hygiene_results)
# Display the number of rows in the DataFrame
print(len(zero_hygiene_df))
# Display the first 10 rows of the DataFrame
zero_hygiene_df.head(10)
# Out:
# 55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
